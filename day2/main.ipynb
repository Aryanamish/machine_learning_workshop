# %% [markdown]
# # <span style="color:#d62d41">Matplot, Pandas, Numpy, Seaborn</span>

# %% [markdown]
# ### <span style="color:#060f54">Name:</span>  <span style="color:#601bcf">Aryan Amish</span>
# ### <span style="color:#060f54">Roll No.:</span> <span style="color:#601bcf">20S115893</span>
# ### <span style="color:#060f54">Reg No.:</span> <span style="color:#601bcf">40110122</span>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot
import random
import seaborn as sns

# %% [markdown]
# ## <span style="color:#e8812c">Reading Data From File</span>

# %%
ds = pd.read_csv("diabetes.csv")
ds.columns = ds.columns.str.lower()
print(ds.columns)
# Out:
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %% [markdown]
# ## <span style="color:#e8812c">The Data Sets</span>

# %%
ds
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ## <span style="color:#e8812c">Box Plot for identifying Outliers</span>

# %%
ds.boxplot(column=['pregnancies'])
# Out:
# <AxesSubplot:>

# %%
pyplot.scatter(ds['bmi'], ds['bmi'])

# %% [markdown]
# ## <span style="color:#e8812c">Fixing the Outliers by z-indexing method</span>

# %%
t = 3
mean = round(ds['bmi'].mean(),2)
std = ds['bmi'].std()
for i in range(len(ds['bmi'])):
    z = (ds['bmi'][i]-mean)/std
    if z > t:
        ds['bmi'][i] = mean

# %% [markdown]
# # <span style="color:#d62d41">MatplotLib</span>

# %%
a = [random.randint(1,100) for i in range(20)]
b = [random.randint(1,100) for i in range(20)]
pyplot.plot(a,b, 'o')

# %% [markdown]
# # <span style="color:#d62d41">Seaborn</span>

# %% [markdown]
# ### <span style="color:#e8812c">pairplot</span>
# <span style="font-style: italic;">shows the relation between all the attributes in the dataframe</span>

# %%
sns.pairplot(ds)

# %% [markdown]
# ### <span style="color:#e8812c">displot</span>
# <span style="font-style: italic;">Shows the Histograph of a attribute</span>

# %%
sns.displot(ds['age'], kde=False, bins=10)

# %%
sns.displot(ds)

# %%
sns.jointplot(data=ds, x="glucose", y="bloodpressure", kind="hex")
